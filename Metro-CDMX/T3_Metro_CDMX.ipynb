# %%
# Clase abstracta
class Problem:
    def __init__(self, initial, goal):
        self.initial = initial # Estado inicial
        self.goal = goal # Meta

    def actions(self, state):
        raise NotImplementedError

    # Función de transición
    def result(self, state, action):
        raise NotImplementedError

    # Función de desempeño
    def is_goal(self, state):
        return self.goal == state

    def action_cost(self, state1, action, state2):
        return 1

    def h(self, state):
        return 0

# %%
class GraphProblem(Problem):
    def __init__(self, initial, goal, graph):
        super().__init__(initial, goal)
        self.graph = graph

    def actions(self, state):
        lista = []
        for key in self.graph[state].keys():
            lista.append(key)
        return lista

    # Función de transición
    def result(self, state, action):
        return action

    def action_cost(self, state1, action, state2):
        return self.graph[state1][state2]

# %%
# Diccionario de líneas del metro con distancias en km y en tiempo

metro_cdmx = {
    "Linea 1": [
        {"origen": "Observatorio", "destino": "Tacubaya", "distancia_km": 1.705, "tiempo_min": 2.5},
        {"origen": "Tacubaya", "destino": "Juanacatlán", "distancia_km": 1.140, "tiempo_min": 2.0},
        {"origen": "Juanacatlán", "destino": "Chapultepec", "distancia_km": 1.046, "tiempo_min": 2.0},
        {"origen": "Chapultepec", "destino": "Sevilla", "distancia_km": 0.501, "tiempo_min": 1.2},
        {"origen": "Sevilla", "destino": "Insurgentes", "distancia_km": 0.643, "tiempo_min": 1.3},
        {"origen": "Insurgentes", "destino": "Cuauhtémoc", "distancia_km": 0.793, "tiempo_min": 1.5},
        {"origen": "Cuauhtémoc", "destino": "Balderas", "distancia_km": 0.430, "tiempo_min": 1.0},
        {"origen": "Balderas", "destino": "Salto del Agua", "distancia_km": 0.458, "tiempo_min": 1.0},
        {"origen": "Salto del Agua", "destino": "Isabel la Católica", "distancia_km": 0.444, "tiempo_min": 1.0},
        {"origen": "Isabel la Católica", "destino": "Pino Suárez", "distancia_km": 0.382, "tiempo_min": 1.0},
        {"origen": "Pino Suárez", "destino": "Merced", "distancia_km": 0.717, "tiempo_min": 1.4},
        {"origen": "Merced", "destino": "Candelaria", "distancia_km": 0.866, "tiempo_min": 1.6},
        {"origen": "Candelaria", "destino": "San Lázaro", "distancia_km": 0.864, "tiempo_min": 1.6},
        {"origen": "San Lázaro", "destino": "Moctezuma", "distancia_km": 0.534, "tiempo_min": 1.2},
        {"origen": "Moctezuma", "destino": "Balbuena", "distancia_km": 0.703, "tiempo_min": 1.4},
        {"origen": "Balbuena", "destino": "Boulevard Puerto Aéreo", "distancia_km": 0.595, "tiempo_min": 1.2},
        {"origen": "Boulevard Puerto Aéreo", "destino": "Gómez Farías", "distancia_km": 0.611, "tiempo_min": 1.3},
        {"origen": "Gómez Farías", "destino": "Zaragoza", "distancia_km": 0.732, "tiempo_min": 1.4},
        {"origen": "Zaragoza", "destino": "Pantitlán", "distancia_km": 1.320, "tiempo_min": 2.2}
    ],
    "Linea 2": [
        {"origen": "Cuatro Caminos", "destino": "Panteones", "distancia_km": 1.639, "tiempo_min": 2.4},
        {"origen": "Panteones", "destino": "Tacuba", "distancia_km": 1.316, "tiempo_min": 2.1},
        {"origen": "Tacuba", "destino": "Cuitláhuac", "distancia_km": 0.637, "tiempo_min": 1.3},
        {"origen": "Cuitláhuac", "destino": "Popotla", "distancia_km": 0.620, "tiempo_min": 1.2},
        {"origen": "Popotla", "destino": "Colegio Militar", "distancia_km": 0.496, "tiempo_min": 1.1},
        {"origen": "Colegio Militar", "destino": "Normal", "distancia_km": 0.516, "tiempo_min": 1.1},
        {"origen": "Normal", "destino": "San Cosme", "distancia_km": 0.657, "tiempo_min": 1.3},
        {"origen": "San Cosme", "destino": "Revolución", "distancia_km": 0.537, "tiempo_min": 1.2},
        {"origen": "Revolución", "destino": "Hidalgo", "distancia_km": 0.587, "tiempo_min": 1.2},
        {"origen": "Hidalgo", "destino": "Bellas Artes", "distancia_km": 0.447, "tiempo_min": 1.0},
        {"origen": "Bellas Artes", "destino": "Allende", "distancia_km": 0.387, "tiempo_min": 1.0},
        {"origen": "Allende", "destino": "Zócalo/Tenochtitlan", "distancia_km": 0.602, "tiempo_min": 1.2},
        {"origen": "Zócalo/Tenochtitlan", "destino": "Pino Suárez", "distancia_km": 0.380, "tiempo_min": 1.0},
        {"origen": "Pino Suárez", "destino": "San Antonio Abad", "distancia_km": 0.817, "tiempo_min": 1.5},
        {"origen": "San Antonio Abad", "destino": "Chabacano", "distancia_km": 0.642, "tiempo_min": 1.3},
        {"origen": "Chabacano", "destino": "Viaducto", "distancia_km": 0.828, "tiempo_min": 1.5},
        {"origen": "Viaducto", "destino": "Xola", "distancia_km": 0.490, "tiempo_min": 1.1},
        {"origen": "Xola", "destino": "Villa de Cortés", "distancia_km": 0.698, "tiempo_min": 1.3},
        {"origen": "Villa de Cortés", "destino": "Nativitas", "distancia_km": 0.750, "tiempo_min": 1.4},
        {"origen": "Nativitas", "destino": "Portales", "distancia_km": 0.924, "tiempo_min": 1.6},
        {"origen": "Portales", "destino": "Ermita", "distancia_km": 0.748, "tiempo_min": 1.4},
        {"origen": "Ermita", "destino": "General Anaya", "distancia_km": 0.838, "tiempo_min": 1.5},
        {"origen": "General Anaya", "destino": "Taxqueña", "distancia_km": 1.330, "tiempo_min": 2.1}
    ],
    "Linea 3": [
        {"origen": "Indios Verdes", "destino": "Deportivo 18 de Marzo", "distancia_km": 1.160, "tiempo_min": 2.0},
        {"origen": "Deportivo 18 de Marzo", "destino": "Potrero", "distancia_km": 0.966, "tiempo_min": 1.7},
        {"origen": "Potrero", "destino": "La Raza", "distancia_km": 1.106, "tiempo_min": 1.9},
        {"origen": "La Raza", "destino": "Tlatelolco", "distancia_km": 1.445, "tiempo_min": 2.3},
        {"origen": "Tlatelolco", "destino": "Guerrero", "distancia_km": 1.042, "tiempo_min": 1.8},
        {"origen": "Guerrero", "destino": "Hidalgo", "distancia_km": 0.712, "tiempo_min": 1.3},
        {"origen": "Hidalgo", "destino": "Juárez", "distancia_km": 0.250, "tiempo_min": 0.8},
        {"origen": "Juárez", "destino": "Balderas", "distancia_km": 0.659, "tiempo_min": 1.2},
        {"origen": "Balderas", "destino": "Niños Héroes", "distancia_km": 0.665, "tiempo_min": 1.2},
        {"origen": "Niños Héroes", "destino": "Hospital General", "distancia_km": 0.559, "tiempo_min": 1.1},
        {"origen": "Hospital General", "destino": "Centro Médico", "distancia_km": 0.653, "tiempo_min": 1.2},
        {"origen": "Centro Médico", "destino": "Etiopía/Plaza de la Transparencia", "distancia_km": 1.119, "tiempo_min": 1.9},
        {"origen": "Etiopía/Plaza de la Transparencia", "destino": "Eugenia", "distancia_km": 0.955, "tiempo_min": 1.7},
        {"origen": "Eugenia", "destino": "División del Norte", "distancia_km": 0.724, "tiempo_min": 1.3},
        {"origen": "División del Norte", "destino": "Zapata", "distancia_km": 0.794, "tiempo_min": 1.4},
        {"origen": "Zapata", "destino": "Coyoacán", "distancia_km": 1.153, "tiempo_min": 2.0},
        {"origen": "Coyoacán", "destino": "Viveros/Derechos Humanos", "distancia_km": 0.908, "tiempo_min": 1.6},
        {"origen": "Viveros/Derechos Humanos", "destino": "Miguel Ángel de Quevedo", "distancia_km": 0.824, "tiempo_min": 1.5},
        {"origen": "Miguel Ángel de Quevedo", "destino": "Copilco", "distancia_km": 1.295, "tiempo_min": 2.1},
        {"origen": "Copilco", "destino": "Universidad", "distancia_km": 1.306, "tiempo_min": 2.2}
    ],
    "Linea 4": [
        {"origen": "Martín Carrera", "destino": "Talismán", "distancia_km": 1.129, "tiempo_min": 1.9},
        {"origen": "Talismán", "destino": "Bondojito", "distancia_km": 0.959, "tiempo_min": 1.6},
        {"origen": "Bondojito", "destino": "Consulado", "distancia_km": 0.645, "tiempo_min": 1.2},
        {"origen": "Consulado", "destino": "Canal del Norte", "distancia_km": 0.884, "tiempo_min": 1.5},
        {"origen": "Canal del Norte", "destino": "Morelos", "distancia_km": 0.910, "tiempo_min": 1.5},
        {"origen": "Morelos", "destino": "Candelaria", "distancia_km": 1.062, "tiempo_min": 1.8},
        {"origen": "Candelaria", "destino": "Fray Servando", "distancia_km": 0.633, "tiempo_min": 1.1},
        {"origen": "Fray Servando", "destino": "Jamaiquita", "distancia_km": 1.031, "tiempo_min": 1.7},
        {"origen": "Jamaiquita", "destino": "Santa Anita", "distancia_km": 0.608, "tiempo_min": 1.1}
    ],
    "Linea 5": [
        {"origen": "Pantitlán", "destino": "Hangares", "distancia_km": 1.649, "tiempo_min": 2.5},
        {"origen": "Hangares", "destino": "Terminal Aérea", "distancia_km": 1.152, "tiempo_min": 1.9},
        {"origen": "Terminal Aérea", "destino": "Oceanía", "distancia_km": 1.174, "tiempo_min": 1.9},
        {"origen": "Oceanía", "destino": "Aragón", "distancia_km": 1.224, "tiempo_min": 2.0},
        {"origen": "Aragón", "destino": "Eduardo Molina", "distancia_km": 0.886, "tiempo_min": 1.5},
        {"origen": "Eduardo Molina", "destino": "Consulado", "distancia_km": 0.833, "tiempo_min": 1.4},
        {"origen": "Consulado", "destino": "Valle Gómez", "distancia_km": 0.679, "tiempo_min": 1.2},
        {"origen": "Valle Gómez", "destino": "Misterios", "distancia_km": 0.969, "tiempo_min": 1.6},
        {"origen": "Misterios", "destino": "La Raza", "distancia_km": 1.002, "tiempo_min": 1.7},
        {"origen": "La Raza", "destino": "Autobuses del Norte", "distancia_km": 1.019, "tiempo_min": 1.7},
        {"origen": "Autobuses del Norte", "destino": "Instituto del Petróleo", "distancia_km": 1.066, "tiempo_min": 1.8},
        {"origen": "Instituto del Petróleo", "destino": "Politécnico", "distancia_km": 1.188, "tiempo_min": 2.0}
    ],
    "Linea 6": [
        {"origen": "El Rosario", "destino": "Tezozómoc", "distancia_km": 1.257, "tiempo_min": 2.1},
        {"origen": "Tezozómoc", "destino": "UAM-Azcapotzalco", "distancia_km": 0.978, "tiempo_min": 1.6},
        {"origen": "UAM-Azcapotzalco", "destino": "Ferrería/Arena Ciudad de México", "distancia_km": 1.173, "tiempo_min": 1.9},
        {"origen": "Ferrería/Arena Ciudad de México", "destino": "Norte 45", "distancia_km": 1.072, "tiempo_min": 1.8},
        {"origen": "Norte 45", "destino": "Vallejo", "distancia_km": 0.660, "tiempo_min": 1.2},
        {"origen": "Vallejo", "destino": "Instituto del Petróleo", "distancia_km": 0.755, "tiempo_min": 1.3},
        {"origen": "Instituto del Petróleo", "destino": "Lindavista", "distancia_km": 1.258, "tiempo_min": 2.1},
        {"origen": "Lindavista", "destino": "Deportivo 18 de Marzo", "distancia_km": 1.075, "tiempo_min": 1.8},
        {"origen": "Deportivo 18 de Marzo", "destino": "La Villa-Basílica", "distancia_km": 0.570, "tiempo_min": 1.1},
        {"origen": "La Villa-Basílica", "destino": "Martín Carrera", "distancia_km": 1.141, "tiempo_min": 1.9}
    ],
    "Linea 7": [
        {"origen": "El Rosario", "destino": "Aquiles Serdán", "distancia_km": 1.615, "tiempo_min": 2.5},
        {"origen": "Aquiles Serdán", "destino": "Camarones", "distancia_km": 0.982, "tiempo_min": 1.6},
        {"origen": "Camarones", "destino": "Refinería", "distancia_km": 0.952, "tiempo_min": 1.6},
        {"origen": "Refinería", "destino": "Tacuba", "distancia_km": 1.297, "tiempo_min": 2.1},
        {"origen": "Tacuba", "destino": "San Joaquín", "distancia_km": 1.433, "tiempo_min": 2.3},
        {"origen": "San Joaquín", "destino": "Polanco", "distancia_km": 1.163, "tiempo_min": 1.9},
        {"origen": "Polanco", "destino": "Auditorio", "distancia_km": 0.850, "tiempo_min": 1.4},
        {"origen": "Auditorio", "destino": "Constituyentes", "distancia_km": 1.430, "tiempo_min": 2.3},
        {"origen": "Constituyentes", "destino": "Tacubaya", "distancia_km": 1.005, "tiempo_min": 1.7},
        {"origen": "Tacubaya", "destino": "San Pedro de los Pinos", "distancia_km": 1.082, "tiempo_min": 1.8},
        {"origen": "San Pedro de los Pinos", "destino": "San Antonio", "distancia_km": 0.606, "tiempo_min": 1.1},
        {"origen": "San Antonio", "destino": "Mixcoac", "distancia_km": 0.788, "tiempo_min": 1.3},
        {"origen": "Mixcoac", "destino": "Barranca del Muerto", "distancia_km": 1.676, "tiempo_min": 2.6}
    ],
    "Linea 8": [
        {"origen": "Garibaldi/Lagunilla", "destino": "Bellas Artes", "distancia_km": 0.634, "tiempo_min": 1.1},
        {"origen": "Bellas Artes", "destino": "San Juan de Letrán", "distancia_km": 0.441, "tiempo_min": 0.9},
        {"origen": "San Juan de Letrán", "destino": "Salto del Agua", "distancia_km": 0.292, "tiempo_min": 0.7},
        {"origen": "Salto del Agua", "destino": "Doctores", "distancia_km": 0.564, "tiempo_min": 1.0},
        {"origen": "Doctores", "destino": "Obrero Mundial", "distancia_km": 0.658, "tiempo_min": 1.2},
        {"origen": "Obrero Mundial", "destino": "Chabacano", "distancia_km": 0.852, "tiempo_min": 1.5},
        {"origen": "Chabacano", "destino": "La Viga", "distancia_km": 0.843, "tiempo_min": 1.5},
        {"origen": "La Viga", "destino": "Santa Anita", "distancia_km": 0.633, "tiempo_min": 1.1},
        {"origen": "Santa Anita", "destino": "Coyuya", "distancia_km": 0.968, "tiempo_min": 1.6},
        {"origen": "Coyuya", "destino": "Iztacalco", "distancia_km": 0.993, "tiempo_min": 1.7},
        {"origen": "Iztacalco", "destino": "Apatlaco", "distancia_km": 0.910, "tiempo_min": 1.5},
        {"origen": "Apatlaco", "destino": "Aculco", "distancia_km": 0.534, "tiempo_min": 1.0},
        {"origen": "Aculco", "destino": "Escuadrón 201", "distancia_km": 0.789, "tiempo_min": 1.3},
        {"origen": "Escuadrón 201", "destino": "Atlalilco", "distancia_km": 1.738, "tiempo_min": 2.7},
        {"origen": "Atlalilco", "destino": "Iztapalapa", "distancia_km": 0.732, "tiempo_min": 1.3},
        {"origen": "Iztapalapa", "destino": "Cerro de la Estrella", "distancia_km": 0.674, "tiempo_min": 1.2},
        {"origen": "Cerro de la Estrella", "destino": "UAM-I", "distancia_km": 1.150, "tiempo_min": 1.9},
        {"origen": "UAM-I", "destino": "Constitución de 1917", "distancia_km": 1.137, "tiempo_min": 1.9}
    ],
    "Linea 9": [
        {"origen": "Pantitlán", "destino": "Puebla", "distancia_km": 1.380, "tiempo_min": 2.2},
        {"origen": "Puebla", "destino": "Ciudad Deportiva", "distancia_km": 0.800, "tiempo_min": 1.4},
        {"origen": "Ciudad Deportiva", "destino": "Velasco Alvarado", "distancia_km": 1.010, "tiempo_min": 1.7},
        {"origen": "Velasco Alvarado", "destino": "Mixiuhca", "distancia_km": 0.722, "tiempo_min": 1.3},
        {"origen": "Mixiuhca", "destino": "Jamaica", "distancia_km": 0.942, "tiempo_min": 1.6},
        {"origen": "Jamaica", "destino": "Chabacano", "distancia_km": 1.031, "tiempo_min": 1.7},
        {"origen": "Chabacano", "destino": "Lázaro Cárdenas", "distancia_km": 1.000, "tiempo_min": 1.7},
        {"origen": "Lázaro Cárdenas", "destino": "Centro Médico", "distancia_km": 1.059, "tiempo_min": 1.8},
        {"origen": "Centro Médico", "destino": "Chilpancingo", "distancia_km": 1.152, "tiempo_min": 1.9},
        {"origen": "Chilpancingo", "destino": "Patriotismo", "distancia_km": 0.955, "tiempo_min": 1.6},
        {"origen": "Patriotismo", "destino": "Tacubaya", "distancia_km": 1.133, "tiempo_min": 1.9}
    ],
    "Linea A": [
        {"origen": "Pantitlán", "destino": "Agrícola Oriental", "distancia_km": 1.409, "tiempo_min": 2.3},
        {"origen": "Agrícola Oriental", "destino": "Canal de San Juan", "distancia_km": 1.193, "tiempo_min": 2.0},
        {"origen": "Canal de San Juan", "destino": "Tepalcates", "distancia_km": 1.456, "tiempo_min": 2.4},
        {"origen": "Tepalcates", "destino": "Guelatao", "distancia_km": 1.161, "tiempo_min": 1.9},
        {"origen": "Guelatao", "destino": "Peñón del Viejo", "distancia_km": 2.206, "tiempo_min": 3.6},
        {"origen": "Peñón del Viejo", "destino": "Acatitla", "distancia_km": 1.343, "tiempo_min": 2.2},
        {"origen": "Acatitla", "destino": "Santa Marta", "distancia_km": 1.100, "tiempo_min": 1.8},
        {"origen": "Santa Marta", "destino": "Los Reyes", "distancia_km": 1.783, "tiempo_min": 2.8},
        {"origen": "Los Reyes", "destino": "La Paz", "distancia_km": 1.956, "tiempo_min": 3.1}
    ],
    "Linea B": [
        {"origen": "Ciudad Azteca", "destino": "Plaza Aragón", "distancia_km": 0.760, "tiempo_min": 1.3},
        {"origen": "Plaza Aragón", "destino": "Olímpica", "distancia_km": 0.709, "tiempo_min": 1.2},
        {"origen": "Olímpica", "destino": "Ecatepec", "distancia_km": 0.596, "tiempo_min": 1.0},
        {"origen": "Ecatepec", "destino": "Múzquiz", "distancia_km": 1.485, "tiempo_min": 2.4},
        {"origen": "Múzquiz", "destino": "Río de los Remedios", "distancia_km": 1.155, "tiempo_min": 1.9},
        {"origen": "Río de los Remedios", "destino": "Impulsora", "distancia_km": 0.436, "tiempo_min": 0.9},
        {"origen": "Impulsora", "destino": "Nezahualcóyotl", "distancia_km": 1.342, "tiempo_min": 2.2},
        {"origen": "Nezahualcóyotl", "destino": "Villa de Aragón", "distancia_km": 1.334, "tiempo_min": 2.1},
        {"origen": "Villa de Aragón", "destino": "Bosque de Aragón", "distancia_km": 0.784, "tiempo_min": 1.3},
        {"origen": "Bosque de Aragón", "destino": "Deportivo Oceanía", "distancia_km": 1.154, "tiempo_min": 1.9},
        {"origen": "Deportivo Oceanía", "destino": "Oceanía", "distancia_km": 0.863, "tiempo_min": 1.4},
        {"origen": "Oceanía", "destino": "Romero Rubio", "distancia_km": 0.809, "tiempo_min": 1.3},
        {"origen": "Romero Rubio", "destino": "Flores Magón", "distancia_km": 0.908, "tiempo_min": 1.5},
        {"origen": "Flores Magón", "destino": "San Lázaro", "distancia_km": 0.909, "tiempo_min": 1.5},
        {"origen": "San Lázaro", "destino": "Morelos", "distancia_km": 1.296, "tiempo_min": 2.1},
        {"origen": "Morelos", "destino": "Tepito", "distancia_km": 0.498, "tiempo_min": 1.0},
        {"origen": "Tepito", "destino": "Lagunilla", "distancia_km": 0.611, "tiempo_min": 1.1},
        {"origen": "Lagunilla", "destino": "Garibaldi/Lagunilla", "distancia_km": 0.374, "tiempo_min": 0.8},
        {"origen": "Garibaldi/Lagunilla", "destino": "Guerrero", "distancia_km": 0.757, "tiempo_min": 1.3},
        {"origen": "Guerrero", "destino": "Buenavista", "distancia_km": 0.500, "tiempo_min": 1.0}
    ],
    "Linea 12": [
        {"origen": "Mixcoac", "destino": "Insurgentes Sur", "distancia_km": 0.651, "tiempo_min": 1.2},
        {"origen": "Insurgentes Sur", "destino": "Hospital 20 de Noviembre", "distancia_km": 0.725, "tiempo_min": 1.3},
        {"origen": "Hospital 20 de Noviembre", "destino": "Zapata", "distancia_km": 0.450, "tiempo_min": 0.9},
        {"origen": "Zapata", "destino": "Parque de los Venados", "distancia_km": 0.560, "tiempo_min": 1.0},
        {"origen": "Parque de los Venados", "destino": "Eje Central", "distancia_km": 1.280, "tiempo_min": 2.1},
        {"origen": "Eje Central", "destino": "Ermita", "distancia_km": 0.800, "tiempo_min": 1.4},
        {"origen": "Ermita", "destino": "Mexicaltzingo", "distancia_km": 1.800, "tiempo_min": 2.8},
        {"origen": "Mexicaltzingo", "destino": "Atlalilco", "distancia_km": 1.922, "tiempo_min": 3.0},
        {"origen": "Atlalilco", "destino": "Culhuacán", "distancia_km": 1.676, "tiempo_min": 2.6},
        {"origen": "Culhuacán", "destino": "San Andrés Tomatlán", "distancia_km": 0.990, "tiempo_min": 1.6},
        {"origen": "San Andrés Tomatlán", "destino": "Lomas Estrella", "distancia_km": 1.060, "tiempo_min": 1.7},
        {"origen": "Lomas Estrella", "destino": "Calle 11", "distancia_km": 0.950, "tiempo_min": 1.5},
        {"origen": "Calle 11", "destino": "Periférico Oriente", "distancia_km": 1.543, "tiempo_min": 2.4},
        {"origen": "Periférico Oriente", "destino": "Tezonco", "distancia_km": 1.545, "tiempo_min": 2.4},
        {"origen": "Tezonco", "destino": "Olivos", "distancia_km": 0.490, "tiempo_min": 0.9},
        {"origen": "Olivos", "destino": "Nopalera", "distancia_km": 1.340, "tiempo_min": 2.1},
        {"origen": "Nopalera", "destino": "Zapotitlán", "distancia_km": 1.240, "tiempo_min": 2.0},
        {"origen": "Zapotitlán", "destino": "Tlaltenco", "distancia_km": 1.300, "tiempo_min": 2.0},
        {"origen": "Tlaltenco", "destino": "Tláhuac", "distancia_km": 1.320, "tiempo_min": 2.1}
    ]
}

# %%
#Función que convierte el diccionario en un diccionario de adyacencia (origen y vecinos)
def convert_metro_to_adjacency_graph(metro_data):
    adjacency_graph = {}
    for line_name, segments in metro_data.items():
        for segment in segments:
            origin = segment['origen']
            destination = segment['destino']
            time_cost = segment['tiempo_min']

            #Agregar origen y vecinos (destinos)
            if origin not in adjacency_graph:
                adjacency_graph[origin] = {}
            adjacency_graph[origin][destination] = time_cost

            #Establece que del origen al vecino y del vecino al origen existe la misma arista
            if destination not in adjacency_graph:
                adjacency_graph[destination] = {}
            adjacency_graph[destination][origin] = time_cost
    return adjacency_graph

#Diccionario de la gráfica (ya hay origen y vecinos)
metro_adjacency_graph = convert_metro_to_adjacency_graph(metro_cdmx)


print("Se creo la gráfica del metro correctamente.")
# Out:
# Se creo la gráfica del metro correctamente.

# %%
class Node:
    def __init__(self, state, parent = None, action = None, path_cost = 0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def path(self):
        lista_path = []
        node = self
        while node:
            lista_path.append(node.state)
            node = node.parent
        return lista_path[::-1]

    def expand(self, problem):
        lista = []
        for action in problem.actions(self.state):
            lista.append(self.child_node(problem, action))
        return lista

    def child_node(self, problem, action):
        next_state = problem.result(self.state, action)
        step_cost = problem.action_cost(self.state, action, next_state)
        return Node(next_state, self, action, self.path_cost + step_cost)

# %%
def depth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = [start_node]
    explored = set()

    while frontier:
        node = frontier.pop()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
from collections import deque

def breadth_first_graph_search(problem):
    start_node = Node(problem.initial)
    if problem.is_goal(start_node.state):
        return start_node
    frontier = deque([start_node])
    explored = set()

    while frontier:
        node = frontier.popleft()
        explored.add(node.state)

        if problem.is_goal(node.state):
            return node

        for child in node.expand(problem):
            if child.state not in explored:
                frontier.append(child)
    return None

# %%
# DFS:  Cuatro Camino -> Pantitlan
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_adjacency_graph)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquín',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velasco Alvarado',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
#BFS: Cuatro caminos -> Pantitlán
problem = GraphProblem("Cuatro Caminos", "Pantitlán", metro_adjacency_graph)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Cuatro Caminos',
#  'Panteones',
#  'Tacuba',
#  'San Joaquín',
#  'Polanco',
#  'Auditorio',
#  'Constituyentes',
#  'Tacubaya',
#  'Patriotismo',
#  'Chilpancingo',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'Jamaica',
#  'Mixiuhca',
#  'Velasco Alvarado',
#  'Ciudad Deportiva',
#  'Puebla',
#  'Pantitlán']

# %%
# DFS: Politécnico -> Taxqueña
problem = GraphProblem("Politécnico", "Taxqueña", metro_adjacency_graph)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
#  'Valle Gómez',
#  'Misterios',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Garibaldi/Lagunilla',
#  'Lagunilla',
#  'Tepito',
#  'Morelos',
#  'San Lázaro',
#  'Flores Magón',
#  'Romero Rubio',
#  'Oceanía',
#  'Terminal Aérea',
#  'Hangares',
#  'Pantitlán',
#  'Puebla',
#  'Ciudad Deportiva',
#  'Velasco Alvarado',
#  'Mixiuhca',
#  'Jamaica',
#  'Chabacano',
#  'Lázaro Cárdenas',
#  'Centro Médico',
#  'Chilpancingo',
#  'Patriotismo',
#  'Tacubaya',
#  'San Pedro de los Pinos',
#  'San Antonio',
#  'Mixcoac',
#  'Insurgentes Sur',
#  'Hospital 20 de Noviembre',
#  'Zapata',
#  'Parque de los Venados',
#  'Eje Central',
#  'Ermita',
#  'General Anaya',
#  'Taxqueña']

# %%
#BFS: Politécnico -> Taxqueña
problem = GraphProblem("Politécnico", "Taxqueña", metro_adjacency_graph)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Politécnico',
#  'Instituto del Petróleo',
#  'Autobuses del Norte',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Hidalgo',
#  'Bellas Artes',
#  'Allende',
#  'Zócalo/Tenochtitlan',
#  'Pino Suárez',
#  'San Antonio Abad',
#  'Chabacano',
#  'Viaducto',
#  'Xola',
#  'Villa de Cortés',
#  'Nativitas',
#  'Portales',
#  'Ermita',
#  'General Anaya',
#  'Taxqueña']

# %%
#BFS: Zapata -> Oceanía
problem = GraphProblem("Zapata", "Oceanía", metro_adjacency_graph)
node = breadth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'División del Norte',
#  'Eugenia',
#  'Etiopía/Plaza de la Transparencia',
#  'Centro Médico',
#  'Lázaro Cárdenas',
#  'Chabacano',
#  'San Antonio Abad',
#  'Pino Suárez',
#  'Merced',
#  'Candelaria',
#  'San Lázaro',
#  'Flores Magón',
#  'Romero Rubio',
#  'Oceanía']

# %%
# DFS: Zapata -> Oceanía
problem = GraphProblem("Zapata", "Oceanía", metro_adjacency_graph)
node = depth_first_graph_search(problem)
node.path()
# Out:
# ['Zapata',
#  'Parque de los Venados',
#  'Eje Central',
#  'Ermita',
#  'Mexicaltzingo',
#  'Atlalilco',
#  'Escuadrón 201',
#  'Aculco',
#  'Apatlaco',
#  'Iztacalco',
#  'Coyuya',
#  'Santa Anita',
#  'La Viga',
#  'Chabacano',
#  'Lázaro Cárdenas',
#  'Centro Médico',
#  'Chilpancingo',
#  'Patriotismo',
#  'Tacubaya',
#  'Constituyentes',
#  'Auditorio',
#  'Polanco',
#  'San Joaquín',
#  'Tacuba',
#  'Refinería',
#  'Camarones',
#  'Aquiles Serdán',
#  'El Rosario',
#  'Tezozómoc',
#  'UAM-Azcapotzalco',
#  'Ferrería/Arena Ciudad de México',
#  'Norte 45',
#  'Vallejo',
#  'Instituto del Petróleo',
#  'Lindavista',
#  'Deportivo 18 de Marzo',
#  'La Villa-Basílica',
#  'Martín Carrera',
#  'Talismán',
#  'Bondojito',
#  'Consulado',
#  'Valle Gómez',
#  'Misterios',
#  'La Raza',
#  'Tlatelolco',
#  'Guerrero',
#  'Garibaldi/Lagunilla',
#  'Lagunilla',
#  'Tepito',
#  'Morelos',
#  'San Lázaro',
#  'Flores Magón',
#  'Romero Rubio',
#  'Oceanía']
